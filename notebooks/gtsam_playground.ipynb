# %%
import sys
import gtsam
import gtsam.utils.plot as gtsam_plot
import matplotlib.pyplot as plt
from gtsam.symbol_shorthand import X
import numpy as np

from typing import Optional
from functools import partial

# %%
p1 = gtsam.Pose2((1,1,np.pi/4))
p1.__getstate__()
# Out:
# ('22 serialization::archive 20 1 0\n0 0 0 5.27393087579049347e-01 1.27323954473516254e+00 1 0\n1 7.07106781186547573e-01 7.07106781186547462e-01\n',)

# %%
# help(gtsam.Marginals)
gtsam.__dir__()
# Out:
# ['__name__',
#  '__doc__',
#  '__package__',
#  '__loader__',
#  '__spec__',
#  '__path__',
#  '__file__',
#  '__cached__',
#  '__builtins__',
#  'sys',
#  'utils',
#  'findExampleDataFile',
#  'gtsam',
#  'MT19937',
#  'IndexPair',
#  'DSFMapIndexPair',
#  'Value',
#  'GenericValueVector',
#  'GenericValueMatrix',
#  'GenericValuePoint2',
#  'GenericValuePoint3',
#  'GenericValueRot2',
#  'GenericValueRot3',
#  'GenericValuePose2',
#  'GenericValuePose3',
#  'GenericValueStereoPoint2',
#  'GenericValueCal3_S2',
#  'GenericValueCal3DS2',
#  'GenericValueCal3Bundler',
#  'GenericValueCal3Fisheye',
#  'GenericValueCal3Unified',
#  'GenericValueEssentialMatrix',
#  'GenericValueCalibratedCamera',
#  'GenericValueConstantBias',
#  'isDebugVersion',
#  'IndexPairSetAsArray',
#  'linear_independent',
#  'Symbol',
#  'symbol_shorthand',
#  'LabeledSymbol',
#  'EdgeKey',
#  'Ordering',
#  'DotWriter',
#  'VariableIndex',
#  'Factor',
#  'PrintKeyList',
#  'PrintKeyVector',
#  'PrintKeySet',
#  'symbol',
#  'symbolChr',
#  'symbolIndex',
#  'mrsymbol',
#  'mrsymbolChr',
#  'mrsymbolLabel',
#  'mrsymbolIndex',
#  'AssignmentKey',
#  'KeysView',
#  'ValuesView',
#  'ItemsView',
#  'DiscreteValues',
#  'PrintDiscreteValues',
#  'DiscreteKeys',
#  'DiscreteFactor',
#  'DecisionTreeFactor',
#  'DiscreteConditional',
#  'DiscreteDistribution',
#  'TableFactor',
#  'TableDistribution',
#  'DiscreteBayesNet',
#  'DiscreteBayesTreeClique',
#  'DiscreteBayesTree',
#  'DiscreteLookupTable',
#  'DiscreteLookupDAG',
#  'DiscreteFactorGraph',
#  'DiscreteEliminationTree',
#  'DiscreteCluster',
#  'DiscreteJunctionTree',
#  'DiscreteSearchSolution',
#  'DiscreteSearch',
#  'DiscreteMarginals',
#  'cartesianProduct',
#  'markdown',
#  'html',
#  'EliminateDiscrete',
#  'EliminateForMPE',
#  'StereoPoint2',
#  'Rot2',
#  'so3',
#  'SO3',
#  'SO4',
#  'SOn',
#  'Quaternion',
#  'Rot3',
#  'Pose2',
#  'Pose3',
#  'ExtendedPose32',
#  'ExtendedPose33',
#  'ExtendedPose34',
#  'ExtendedPose36',
#  'ExtendedPose3d',
#  'SL4',
#  'Unit3',
#  'OrientedPlane3',
#  'EssentialMatrix',
#  'Similarity2',
#  'Similarity3',
#  'Event',
#  'Gal3',
#  'BearingRange2D',
#  'BearingRangePose2',
#  'BearingRange3D',
#  'BearingRangePose3',
#  'CameraSetCal3_S2',
#  'CameraSetCal3DS2',
#  'CameraSetCal3Bundler',
#  'CameraSetCal3Unified',
#  'CameraSetCal3Fisheye',
#  'CameraSetSpherical',
#  'Cal3',
#  'Cal3_S2',
#  'Cal3DS2_Base',
#  'Cal3DS2',
#  'Cal3Unified',
#  'Cal3Fisheye',
#  'Cal3_S2Stereo',
#  'Cal3f',
#  'Cal3Bundler',
#  'FundamentalMatrix',
#  'SimpleFundamentalMatrix',
#  'CalibratedCamera',
#  'SphericalCamera',
#  'CameraSetPinholePoseCal3_S2',
#  'StereoCamera',
#  'TriangulationResult',
#  'TriangulationParameters',
#  'PinholeCameraCal3_S2',
#  'PinholeCameraCal3DS2',
#  'PinholeCameraCal3Unified',
#  'PinholeCameraCal3Bundler',
#  'PinholeCameraCal3f',
#  'PinholeCameraCal3Fisheye',
#  'PinholePoseCal3_S2',
#  'PinholePoseCal3DS2',
#  'PinholePoseCal3Unified',
#  'PinholePoseCal3Bundler',
#  'PinholePoseCal3Fisheye',
#  'EpipolarTransfer',
#  'triangulatePoint3',
#  'triangulateNonlinear',
#  'triangulateSafe',
#  'noiseModel',
#  'Sampler',
#  'VectorValues',
#  'GaussianFactor',
#  'JacobianFactor',
#  'HessianFactor',
#  'GaussianFactorGraph',
#  'GaussianConditional',
#  'GaussianDensity',
#  'GaussianBayesNet',
#  'GaussianBayesTreeClique',
#  'GaussianBayesTree',
#  'GaussianEliminationTree',
#  'GaussianISAM',
#  'IterativeOptimizationParameters',
#  'ConjugateGradientParameters',
#  'PreconditionerParameters',
#  'DummyPreconditionerParameters',
#  'BlockJacobiPreconditionerParameters',
#  'PCGSolverParameters',
#  'SubgraphSolverParameters',
#  'SubgraphSolver',
#  'KalmanFilter',
#  'EliminateQR',
#  'GraphvizFormatting',
#  'NonlinearFactorGraph',
#  'NonlinearFactor',
#  'NoiseModelFactor',
#  'Marginals',
#  'JointMarginal',
#  'LinearContainerFactor',
#  'NonlinearOptimizerParams',
#  'GaussNewtonParams',
#  'LevenbergMarquardtParams',
#  'DoglegParams',
#  'GncLossType',
#  'GncScheduler',
#  'NonlinearOptimizer',
#  'GaussNewtonOptimizer',
#  'DoglegOptimizer',
#  'LevenbergMarquardtOptimizer',
#  'ISAM2GaussNewtonParams',
#  'ISAM2DoglegParams',
#  'ISAM2DoglegLineSearchParams',
#  'ISAM2ThresholdMap',
#  'ISAM2Params',
#  'ISAM2Clique',
#  'ISAM2Result',
#  'ISAM2',
#  'NonlinearISAM',
#  'PriorFactorDouble',
#  'PriorFactorVector',
#  'PriorFactorPoint2',
#  'PriorFactorStereoPoint2',
#  'PriorFactorPoint3',
#  'PriorFactorGal3',
#  'PriorFactorRot2',
#  'PriorFactorSO3',
#  'PriorFactorSO4',
#  'PriorFactorSOn',
#  'PriorFactorSL4',
#  'PriorFactorRot3',
#  'PriorFactorPose2',
#  'PriorFactorPose3',
#  'PriorFactorSimilarity2',
#  'PriorFactorSimilarity3',
#  'PriorFactorUnit3',
#  'PriorFactorCal3_S2',
#  'PriorFactorCal3DS2',
#  'PriorFactorCal3Bundler',
#  'PriorFactorCal3Fisheye',
#  'PriorFactorCal3Unified',
#  'PriorFactorCalibratedCamera',
#  'PriorFactorPinholeCameraCal3_S2',
#  'PriorFactorPinholeCameraCal3Bundler',
#  'PriorFactorPinholeCameraCal3Fisheye',
#  'PriorFactorPinholeCameraCal3Unified',
#  'PriorFactorSphericalCamera',
#  'PriorFactorNavState',
#  'PriorFactorConstantBias',
#  'ExtendedPriorFactorDouble',
#  'ExtendedPriorFactorVector',
#  'ExtendedPriorFactorPoint2',
#  'ExtendedPriorFactorStereoPoint2',
#  'ExtendedPriorFactorPoint3',
#  'ExtendedPriorFactorGal3',
#  'ExtendedPriorFactorRot2',
#  'ExtendedPriorFactorSO3',
#  'ExtendedPriorFactorSO4',
#  'ExtendedPriorFactorSOn',
#  'ExtendedPriorFactorSL4',
#  'ExtendedPriorFactorRot3',
#  'ExtendedPriorFactorPose2',
#  'ExtendedPriorFactorPose3',
#  'ExtendedPriorFactorSimilarity2',
#  'ExtendedPriorFactorSimilarity3',
#  'ExtendedPriorFactorUnit3',
#  'ExtendedPriorFactorCal3_S2',
#  'ExtendedPriorFactorCal3DS2',
#  'ExtendedPriorFactorCal3Bundler',
#  'ExtendedPriorFactorCal3Fisheye',
#  'ExtendedPriorFactorCal3Unified',
#  'ExtendedPriorFactorCalibratedCamera',
#  'ExtendedPriorFactorPinholeCameraCal3_S2',
#  'ExtendedPriorFactorPinholeCameraCal3Bundler',
#  'ExtendedPriorFactorPinholeCameraCal3Fisheye',
#  'ExtendedPriorFactorPinholeCameraCal3Unified',
#  'ExtendedPriorFactorNavState',
#  'ExtendedPriorFactorConstantBias',
#  'ConcentratedGaussianDouble',
#  'ConcentratedGaussianVector',
#  'ConcentratedGaussianPoint2',
#  'ConcentratedGaussianStereoPoint2',
#  'ConcentratedGaussianPoint3',
#  'ConcentratedGaussianGal3',
#  'ConcentratedGaussianRot2',
#  'ConcentratedGaussianSO3',
#  'ConcentratedGaussianSO4',
#  'ConcentratedGaussianSOn',
#  'ConcentratedGaussianSL4',
#  'ConcentratedGaussianRot3',
#  'ConcentratedGaussianPose2',
#  'ConcentratedGaussianPose3',
#  'ConcentratedGaussianSimilarity2',
#  'ConcentratedGaussianSimilarity3',
#  'NonlinearEqualityPoint2',
#  'NonlinearEqualityStereoPoint2',
#  'NonlinearEqualityPoint3',
#  'NonlinearEqualityRot2',
#  'NonlinearEqualitySO3',
#  'NonlinearEqualitySO4',
#  'NonlinearEqualitySOn',
#  'NonlinearEqualitySL4',
#  'NonlinearEqualityRot3',
#  'NonlinearEqualityPose2',
#  'NonlinearEqualityGal3',
#  'NonlinearEqualityPose3',
#  'NonlinearEqualitySimilarity2',
#  'NonlinearEqualitySimilarity3',
#  'NonlinearEqualityCal3_S2',
#  'NonlinearEqualityCalibratedCamera',
#  'NonlinearEqualityPinholeCameraCal3_S2',
#  'NonlinearEqualityPinholeCameraCal3Bundler',
#  'NonlinearEqualityPinholeCameraCal3Fisheye',
#  'NonlinearEqualityPinholeCameraCal3Unified',
#  'NonlinearEqualitySphericalCamera',
#  'NonlinearEqualityConstantBias',
#  'NonlinearEquality2Point2',
#  'NonlinearEquality2StereoPoint2',
#  'NonlinearEquality2Point3',
#  'NonlinearEquality2Rot2',
#  'NonlinearEquality2Gal3',
#  'NonlinearEquality2SO3',
#  'NonlinearEquality2SO4',
#  'NonlinearEquality2SOn',
#  'NonlinearEquality2SL4',
#  'NonlinearEquality2Rot3',
#  'NonlinearEquality2Pose2',
#  'NonlinearEquality2Pose3',
#  'NonlinearEquality2Similarity2',
#  'NonlinearEquality2Similarity3',
#  'NonlinearEquality2Cal3_S2',
#  'NonlinearEquality2CalibratedCamera',
#  'NonlinearEquality2PinholeCameraCal3_S2',
#  'NonlinearEquality2PinholeCameraCal3Bundler',
#  'NonlinearEquality2PinholeCameraCal3Fisheye',
#  'NonlinearEquality2PinholeCameraCal3Unified',
#  'NonlinearEquality2ConstantBias',
#  'FixedLagSmootherResult',
#  'FixedLagSmoother',
#  'BatchFixedLagSmoother',
#  'IncrementalFixedLagSmoother',
#  'ExtendedKalmanFilterPoint2',
#  'ExtendedKalmanFilterPoint3',
#  'ExtendedKalmanFilterRot2',
#  'ExtendedKalmanFilterRot3',
#  'ExtendedKalmanFilterPose2',
#  'ExtendedKalmanFilterPose3',
#  'ExtendedKalmanFilterGal3',
#  'ExtendedKalmanFilterSL4',
#  'ExtendedKalmanFilterSimilarity2',
#  'ExtendedKalmanFilterSimilarity3',
#  'ExtendedKalmanFilterNavState',
#  'ExtendedKalmanFilterConstantBias',
#  'GncGaussNewtonParams',
#  'GncLMParams',
#  'GncGaussNewtonOptimizer',
#  'GncLMOptimizer',
#  'checkConvergence',
#  'Values',
#  'JacobianVector',
#  'CustomFactor',
#  'SymbolicFactor',
#  'SymbolicFactorGraph',
#  'SymbolicConditional',
#  'SymbolicBayesNet',
#  'SymbolicEliminationTree',
#  'SymbolicCluster',
#  'SymbolicJunctionTree',
#  'SymbolicBayesTreeClique',
#  'SymbolicBayesTree',
#  'RangeFactor2',
#  'RangeFactor3',
#  'RangeFactor2D',
#  'RangeFactorPose2',
#  'RangeFactor3D',
#  'RangeFactorPose3',
#  'RangeFactorCalibratedCameraPoint',
#  'RangeFactorSimpleCameraPoint',
#  'RangeFactorCalibratedCamera',
#  'RangeFactorSimpleCamera',
#  'RangeFactorWithTransform2D',
#  'RangeFactorWithTransform3D',
#  'RangeFactorWithTransformPose2',
#  'RangeFactorWithTransformPose3',
#  'BearingFactor2D',
#  'BearingFactor3D',
#  'BearingFactorPose2',
#  'BearingRangeFactor2D',
#  'BearingRangeFactorPose2',
#  'BearingRangeFactor3D',
#  'BearingRangeFactorPose3',
#  'BetweenFactorDouble',
#  'BetweenFactorVector',
#  'BetweenFactorPoint2',
#  'BetweenFactorPoint3',
#  'BetweenFactorRot2',
#  'BetweenFactorSO3',
#  'BetweenFactorSO4',
#  'BetweenFactorSL4',
#  'BetweenFactorRot3',
#  'BetweenFactorPose2',
#  'BetweenFactorPose3',
#  'BetweenFactorSimilarity2',
#  'BetweenFactorSimilarity3',
#  'BetweenFactorConstantBias',
#  'PlanarProjectionFactor1',
#  'PlanarProjectionFactor2',
#  'PlanarProjectionFactor3',
#  'GeneralSFMFactor2Cal3_S2',
#  'GeneralSFMFactor2Cal3DS2',
#  'GeneralSFMFactor2Cal3f',
#  'GeneralSFMFactor2Cal3Bundler',
#  'GeneralSFMFactor2Cal3Fisheye',
#  'GeneralSFMFactor2Cal3Unified',
#  'SmartFactorBasePinholeCameraCal3_S2',
#  'SmartFactorBasePinholeCameraCal3DS2',
#  'SmartFactorBasePinholeCameraCal3Bundler',
#  'SmartFactorBasePinholeCameraCal3Fisheye',
#  'SmartFactorBasePinholeCameraCal3Unified',
#  'SmartFactorBasePinholePoseCal3_S2',
#  'SmartFactorBasePinholePoseCal3DS2',
#  'SmartFactorBasePinholePoseCal3Bundler',
#  'SmartFactorBasePinholePoseCal3Fisheye',
#  'SmartFactorBasePinholePoseCal3Unified',
#  'SmartFactorBaseSphericalCamera',
#  'LinearizationMode',
#  'DegeneracyMode',
#  'SmartProjectionParams',
#  'SmartProjectionFactorPinholeCameraCal3_S2',
#  'SmartProjectionFactorPinholeCameraCal3DS2',
#  'SmartProjectionFactorPinholeCameraCal3Bundler',
#  'SmartProjectionFactorPinholeCameraCal3Fisheye',
#  'SmartProjectionFactorPinholeCameraCal3Unified',
#  'SmartProjectionFactorPinholePoseCal3_S2',
#  'SmartProjectionFactorPinholePoseCal3DS2',
#  'SmartProjectionFactorPinholePoseCal3Bundler',
#  'SmartProjectionFactorPinholePoseCal3Fisheye',
#  'SmartProjectionFactorPinholePoseCal3Unified',
#  'SmartProjectionFactorSphericalCamera',
#  'SmartProjectionPoseFactorCal3_S2',
#  'SmartProjectionPoseFactorCal3DS2',
#  'SmartProjectionPoseFactorCal3Bundler',
#  'SmartProjectionPoseFactorCal3Fisheye',
#  'SmartProjectionPoseFactorCal3Unified',
#  'SmartProjectionRigFactorPinholePoseCal3_S2',
#  'SmartProjectionRigFactorPinholePoseCal3DS2',
#  'SmartProjectionRigFactorPinholePoseCal3Bundler',
#  'SmartProjectionRigFactorPinholePoseCal3Fisheye',
#  'SmartProjectionRigFactorPinholePoseCal3Unified',
#  'SmartProjectionRigFactorSphericalCamera',
#  'ReferenceFrameFactorPoint3Pose3',
#  'RotateFactor',
#  'RotateDirectionsFactor',
#  'OrientedPlane3Factor',
#  'OrientedPlane3DirectionPrior',
#  'EssentialMatrixFactor',
#  'EssentialMatrixFactor2',
#  'EssentialMatrixFactor3',
#  'EssentialMatrixFactor4Cal3_S2',
#  'EssentialMatrixFactor4Cal3DS2',
#  'EssentialMatrixFactor4Cal3f',
#  'EssentialMatrixFactor4Cal3Bundler',
#  'EssentialMatrixFactor4Cal3Fisheye',
#  'EssentialMatrixFactor4Cal3Unified',
#  'EssentialMatrixFactor5Cal3_S2',
#  'EssentialMatrixFactor5Cal3DS2',
#  'EssentialMatrixFactor5Cal3f',
#  'EssentialMatrixFactor5Cal3Bundler',
#  'EssentialMatrixFactor5Cal3Fisheye',
#  'EssentialMatrixFactor5Cal3Unified',
#  'EssentialMatrixConstraint',
#  'NoiseFormat',
#  'KernelFunctionType',
#  'InitializePose3',
#  'KarcherMeanFactorRot2',
#  'KarcherMeanFactorPose2',
#  'KarcherMeanFactorSO3',
#  'KarcherMeanFactorSO4',
#  'KarcherMeanFactorRot3',
#  'KarcherMeanFactorPose3',
#  'KarcherMeanFactorSimilarity2',
#  'KarcherMeanFactorSimilarity3',
#  'KarcherMeanFactorGal3',
#  'KarcherMeanFactorSL4',
#  'FrobeniusPriorRot2',
#  'FrobeniusPriorRot3',
#  'FrobeniusPriorSO3',
#  'FrobeniusPriorSO4',
#  'FrobeniusPriorPose2',
#  'FrobeniusPriorPose3',
#  'FrobeniusPriorSimilarity2',
#  'FrobeniusPriorSimilarity3',
#  'FrobeniusPriorGal3',
#  'FrobeniusPriorSL4',
#  'FrobeniusFactorRot2',
#  'FrobeniusFactorRot3',
#  'FrobeniusFactorSO3',
#  'FrobeniusFactorSO4',
#  'FrobeniusFactorPose2',
#  'FrobeniusFactorPose3',
#  'FrobeniusFactorSimilarity2',
#  'FrobeniusFactorSimilarity3',
#  'FrobeniusFactorGal3',
#  'FrobeniusFactorSL4',
#  'FrobeniusBetweenFactorNLRot2',
#  'FrobeniusBetweenFactorNLRot3',
#  'FrobeniusBetweenFactorNLSO3',
#  'FrobeniusBetweenFactorNLSO4',
#  'FrobeniusBetweenFactorNLPose2',
#  'FrobeniusBetweenFactorNLPose3',
#  'FrobeniusBetweenFactorNLSimilarity2',
#  'FrobeniusBetweenFactorNLSimilarity3',
#  'FrobeniusBetweenFactorNLGal3',
#  'FrobeniusBetweenFactorNLSL4',
#  'FrobeniusBetweenFactorRot2',
#  'FrobeniusBetweenFactorRot3',
#  'FrobeniusBetweenFactorSO3',
#  'FrobeniusBetweenFactorSO4',
#  'FrobeniusBetweenFactorPose2',
#  'FrobeniusBetweenFactorPose3',
#  'FrobeniusBetweenFactorGal3',
#  'lago',
#  'GenericProjectionFactorCal3_S2',
#  'GenericProjectionFactorCal3DS2',
#  'GenericProjectionFactorCal3Fisheye',
#  'GenericProjectionFactorCal3Unified',
#  'GeneralSFMFactorCal3_S2',
#  'GeneralSFMFactorCal3DS2',
#  'GeneralSFMFactorCal3Bundler',
#  'GeneralSFMFactorCal3Fisheye',
#  'GeneralSFMFactorCal3Unified',
#  'GeneralSFMFactorPoseCal3_S2',
#  'GeneralSFMFactorPoseCal3DS2',
#  'GeneralSFMFactorPoseCal3Bundler',
#  'GeneralSFMFactorPoseCal3Fisheye',
#  'GeneralSFMFactorPoseCal3Unified',
#  'GeneralSFMFactorSphericalCamera',
#  'GenericStereoFactor3D',
#  'PoseTranslationPrior2D',
#  'PoseTranslationPrior3D',
#  'PoseRotationPrior2D',
#  'PoseRotationPrior3D',
#  'TriangulationFactorCal3_S2',
#  'TriangulationFactorCal3DS2',
#  'TriangulationFactorCal3Bundler',
#  'TriangulationFactorCal3Fisheye',
#  'TriangulationFactorCal3Unified',
#  'TriangulationFactorPoseCal3_S2',
#  'TriangulationFactorPoseCal3DS2',
#  'TriangulationFactorPoseCal3Bundler',
#  'TriangulationFactorPoseCal3Fisheye',
#  'TriangulationFactorPoseCal3Unified',
#  'load2D',
#  'save2D',
#  'parse2DFactors',
#  'parse3DFactors',
#  'load3D',
#  'readG2o',
#  'writeG2o',
#  'FindKarcherMeanRot2',
#  'FindKarcherMeanPose2',
#  'FindKarcherMeanSO3',
#  'FindKarcherMeanSO4',
#  'FindKarcherMeanRot3',
#  'FindKarcherMeanPose3',
#  'FindKarcherMeanSimilarity2',
#  'FindKarcherMeanSimilarity3',
#  'FindKarcherMeanGal3',
#  'FindKarcherMeanSL4',
#  'ConvertNoiseModel',
#  'SfmTrack2d',
#  'SfmTrack',
#  'SfmData',
#  'TransferFactorSimpleFundamentalMatrix',
#  'TransferFactorFundamentalMatrix',
#  'EssentialTransferFactorCal3_S2',
#  'EssentialTransferFactorCal3f',
#  'EssentialTransferFactorCal3Bundler',
#  'EssentialTransferFactorKCal3_S2',
#  'EssentialTransferFactorKCal3f',
#  'EssentialTransferFactorKCal3Bundler',
#  'ShonanFactor3',
#  'TrajectoryAlignerSim3',
#  'ShonanAveragingParameters2',
#  'ShonanAveragingParameters3',
#  'ShonanAveraging2',
#  'ShonanAveraging3',
#  'MFAS',
#  'TranslationRecovery',
#  'gtsfm',
#  'UnaryMeasurementPose3',
#  'UnaryMeasurementRot3',
#  'UnaryMeasurementPoint3',
#  'BinaryMeasurementUnit3',
#  'BinaryMeasurementRot3',
#  'BinaryMeasurementPoint3',
#  'readBal',
#  'writeBAL',
#  'initialCamerasEstimate',
#  'initialCamerasAndPointsEstimate',
#  'imuBias',
#  'NavState',
#  'PreintegratedRotationParams',
#  'PreintegratedRotation',
#  'PreintegrationParams',
#  'PreintegratedImuMeasurements',
#  'ImuFactor',
#  'ImuFactor2',
#  'PreintegrationCombinedParams',
#  'PreintegratedCombinedMeasurements',
#  'CombinedImuFactor',
#  'PreintegratedAhrsMeasurements',
#  'AHRSFactor',
#  'Rot3AttitudeFactor',
#  'Pose3AttitudeFactor',
#  'GPSFactor',
#  'GPSFactorArm',
#  'GPSFactorArmCalib',
#  'GPSFactor2',
#  'GPSFactor2Arm',
#  'GPSFactor2ArmCalib',
#  'PseudorangeFactor',
#  'DifferentialPseudorangeFactor',
#  'BarometricFactor',
#  'ConstantVelocityFactor',
#  'MagFactor',
#  'MagFactor1',
#  'MagPoseFactorPose2',
#  'MagPoseFactorPose3',
#  'Scenario',
#  'ConstantTwistScenario',
#  'AcceleratingScenario',
#  'DiscreteScenario',
#  'ScenarioRunner',
#  'ManifoldEKFUnit3',
#  'ManifoldEKFRot3',
#  'ManifoldEKFPose2',
#  'ManifoldEKFPose3',
#  'ManifoldEKFNavState',
#  'ManifoldEKFGal3',
#  'LieGroupEKFRot3',
#  'LieGroupEKFPose2',
#  'LieGroupEKFPose3',
#  'LieGroupEKFNavState',
#  'LieGroupEKFGal3',
#  'LeftLinearEKFRot3',
#  'LeftLinearEKFPose2',
#  'LeftLinearEKFPose3',
#  'LeftLinearEKFNavState',
#  'LeftLinearEKFGal3',
#  'InvariantEKFRot3',
#  'InvariantEKFPose2',
#  'InvariantEKFPose3',
#  'InvariantEKFNavState',
#  'InvariantEKFGal3',
#  'abc',
#  'NavStateImuEKF',
#  'Gal3ImuEKF',
#  'ContactMeasurement',
#  'LeggedEstimatorParams',
#  'LeggedEstimator',
#  'LeggedInvariantEKF',
#  'LeggedInvariantIEKF',
#  'LeggedFixedLagSmoother',
#  'LeggedCombinedFixedLagSmoother',
#  'FourierBasis',
#  'Chebyshev1Basis',
#  'Chebyshev2Basis',
#  'Chebyshev2',
#  'EvaluationFactorChebyshev2',
#  'EvaluationFactorChebyshev1Basis',
#  'EvaluationFactorChebyshev2Basis',
#  'EvaluationFactorFourierBasis',
#  'VectorEvaluationFactorFourierBasis',
#  'VectorEvaluationFactorChebyshev1Basis',
#  'VectorEvaluationFactorChebyshev2Basis',
#  'VectorEvaluationFactorChebyshev2',
#  'VectorComponentFactorFourierBasis',
#  'VectorComponentFactorChebyshev1Basis',
#  'VectorComponentFactorChebyshev2Basis',
#  'VectorComponentFactorChebyshev2',
#  'ManifoldEvaluationFactorFourierBasisRot2',
#  'ManifoldEvaluationFactorFourierBasisRot3',
#  'ManifoldEvaluationFactorFourierBasisPose2',
#  'ManifoldEvaluationFactorFourierBasisPose3',
#  'ManifoldEvaluationFactorChebyshev1BasisRot2',
#  'ManifoldEvaluationFactorChebyshev1BasisRot3',
#  'ManifoldEvaluationFactorChebyshev1BasisPose2',
#  'ManifoldEvaluationFactorChebyshev1BasisPose3',
#  'ManifoldEvaluationFactorChebyshev2BasisRot2',
#  'ManifoldEvaluationFactorChebyshev2BasisRot3',
#  'ManifoldEvaluationFactorChebyshev2BasisPose2',
#  'ManifoldEvaluationFactorChebyshev2BasisPose3',
#  'ManifoldEvaluationFactorChebyshev2Rot2',
#  'ManifoldEvaluationFactorChebyshev2Rot3',
#  'ManifoldEvaluationFactorChebyshev2Pose2',
#  'ManifoldEvaluationFactorChebyshev2Pose3',
#  'DerivativeFactorFourierBasis',
#  'DerivativeFactorChebyshev1Basis',
#  'DerivativeFactorChebyshev2Basis',
#  'DerivativeFactorChebyshev2',
#  'VectorDerivativeFactorFourierBasis',
#  'VectorDerivativeFactorChebyshev1Basis',
#  'VectorDerivativeFactorChebyshev2Basis',
#  'VectorDerivativeFactorChebyshev2',
#  'ComponentDerivativeFactorFourierBasis',
#  'ComponentDerivativeFactorChebyshev1Basis',
#  'ComponentDerivativeFactorChebyshev2Basis',
#  'ComponentDerivativeFactorChebyshev2',
#  'FitBasisFourierBasis',
#  'FitBasisChebyshev1Basis',
#  'FitBasisChebyshev2Basis',
#  'FitBasisChebyshev2',
#  'HybridValues',
#  'AlgebraicDecisionTreeKey',
#  'HybridFactor',
#  'HybridConditional',
#  'HybridGaussianFactor',
#  'HybridGaussianConditional',
#  'HybridBayesTreeClique',
#  'HybridBayesTree',
#  'HybridBayesNet',
#  'HybridFactorGraph',
#  'HybridGaussianFactorGraph',
#  'HybridNonlinearFactorGraph',
#  'HybridNonlinearFactor',
#  'HybridSmoother',
#  'HybridGaussianISAM',
#  'HybridNonlinearISAM',
#  'HybridEliminationTree',
#  'HybridJunctionTree',
#  'HybridOrdering',
#  'DefaultKeyFormatter',
#  'KeyList',
#  'KeySet',
#  'KeyGroupMap',
#  'utilities',
#  'RedirectCout',
#  'KeyVector',
#  'IndexPairSetMap',
#  'IndexPairVector',
#  'Point2Vector',
#  'Pose3Vector',
#  'Rot3Vector',
#  'Point2Pairs',
#  'Point3Pairs',
#  'Pose2Pairs',
#  'Pose3Pairs',
#  'BinaryMeasurementsPoint3',
#  'BinaryMeasurementsUnit3',
#  'BinaryMeasurementsRot3',
#  'KeyPairDoubleMap',
#  'SfmTrack2dVector',
#  'SfmTracks',
#  'SfmCameras',
#  'SfmMeasurementVector',
#  'MatchIndicesMap',
#  'KeypointsVector',
#  'BetweenFactorPose3s',
#  'BetweenFactorPose2s',
#  'FixedLagSmootherKeyTimestampMap',
#  '_init',
#  'Point2',
#  'Point3']

# %%
print("Python executable:", sys.executable)
print("GTSAM module file:", gtsam.__file__)
# Out:
# Python executable: /Users/ovar/miniforge3/envs/gtsam_dbg/bin/python
# GTSAM module file: /Users/ovar/.local/lib/python3.10/site-packages/gtsam/__init__.py

# %% [markdown]
# ## 2 Modeling Robot Motion
# ### 2.2 Creating a Factor Graph

# %%
# Create an empty nonlinear factor graph
graph = gtsam.NonlinearFactorGraph()

# Add a Gaussian prior on pose x_1
priorMean = gtsam.Pose2(0.0, 0.0, 0.0)
priorNoise = gtsam.noiseModel.Diagonal.Sigmas(np.array([0.3, 0.3, 0.1])) 
graph.add(gtsam.PriorFactorPose2(1, priorMean, priorNoise))

# Add two odemetry factors
odometry = gtsam.Pose2(2.0, 0.0, 0.0)
odometryNoise = gtsam.noiseModel.Diagonal.Sigmas(np.array([0.2, 0.2, 0.1]))
graph.add(gtsam.BetweenFactorPose2(1, 2, odometry, odometryNoise))
graph.add(gtsam.BetweenFactorPose2(2, 3, odometry, odometryNoise))

graph.print("Factor Graph:\n")
# Out:
# Factor Graph:
# size: 3
#
# Factor 0: PriorFactor on 1
#   prior mean:  (0, 0, 0)
#   noise model: diagonal sigmas [0.3; 0.3; 0.1];
#
# Factor 1: BetweenFactor(1,2)
#   measured:  (2, 0, 0)
#   noise model: diagonal sigmas [0.2; 0.2; 0.1];
#
# Factor 2: BetweenFactor(2,3)
#   measured:  (2, 0, 0)
#   noise model: diagonal sigmas [0.2; 0.2; 0.1];

# %% [markdown]
# ### 2.4 Non-linear Optimization in GTSAM

# %%
1 # create (deliberatly inaccurate) initial estimate
initial = gtsam.Values()
initial.insert(1, gtsam.Pose2(0.5, 0.0, 0.2))
initial.insert(2, gtsam.Pose2(2.3, 0.1, -0.2))
initial.insert(3, gtsam.Pose2(4.1, 0.1, 0.1))

result = gtsam.LevenbergMarquardtOptimizer(graph, initial).optimize()
result.print("Result:\n")
# Out:
# Result:
#
# Values with 3 values:
# Value 1: (gtsam::Pose2)
# (7.46978315e-16, -5.34409096e-16, -1.78381863e-16)
#
# Value 2: (gtsam::Pose2)
# (2, -1.09236636e-15, -2.48671179e-16)
#
# Value 3: (gtsam::Pose2)
# (4, -1.70076056e-15, -2.50943863e-16)

# %%
gaussian_fg = graph.linearize(result)
bayes_tree, factor_graph = gaussian_fg.eliminatePartialMultifrontal([1])

# bayes_tree.print("Bayes Tree:\n")
# factor_graph.print("Factor Graph:\n")
marg = factor_graph.eliminateMultifrontal()
fg = gtsam.GaussianFactorGraph(marg)
info = fg.augmentedHessian()[:-1,:-1]
cov = np.linalg.inv(info)
print(np.array2string(cov, formatter={"float_kind": lambda x: f"{x:.2f}"}))
# Out:
# [[0.13 0.00 0.00 0.13 0.00 0.00]
#  [0.00 0.17 0.02 0.00 0.21 0.02]
#  [0.00 0.02 0.02 0.00 0.06 0.02]
#  [0.13 0.00 0.00 0.17 0.00 0.00]
#  [0.00 0.21 0.06 0.00 0.37 0.06]
#  [0.00 0.02 0.02 0.00 0.06 0.03]]

# %% [markdown]
# #### Full Posterio Inference

# %%
marginals = gtsam.Marginals(graph, result)
np.set_printoptions(precision=3, suppress=True)
# marginals.print("Marginals:\n")
print("x1 covariance:\n" + str(marginals.marginalCovariance(1)))
print("x2 covariance:\n" + str(marginals.marginalCovariance(2)))
print("x3 covariance:\n" + str(marginals.marginalCovariance(3)))
# Out:
# x1 covariance:
# [[0.09 0.   0.  ]
#  [0.   0.09 0.  ]
#  [0.   0.   0.01]]
# x2 covariance:
# [[0.13 0.   0.  ]
#  [0.   0.17 0.02]
#  [0.   0.02 0.02]]
# x3 covariance:
# [[0.17 0.   0.  ]
#  [0.   0.37 0.06]
#  [0.   0.06 0.03]]

# %%
gtsam_plot.plot_pose2(0, result.atPose2(1), 0.5, marginals.marginalCovariance(1))
gtsam_plot.plot_pose2(0, result.atPose2(2), 0.5, marginals.marginalCovariance(2))
gtsam_plot.plot_pose2(0, result.atPose2(3), 0.5, marginals.marginalCovariance(3))
plt.axis('equal')
plt.grid('on')
plt.show()

# %% [markdown]
# ## 3 Robot Localization
# ### 3.3 Using Custom Factors
#
# https://gitlab.sintef.no/nix-flakes/gtsam/-/blob/master/python/CustomFactors.md
# https://github.com/borglab/gtsam/blob/develop/gtsam/nonlinear/doc/CustomFactor.ipynb
# https://github.com/borglab/gtsam/blob/develop/python/gtsam/examples/CustomFactorExample.py

# %%
def error_gps(measurement: np.ndarray,
              this: gtsam.CustomFactor,
              values: gtsam.Values, 
              H: Optional[list[np.ndarray]]) -> np.ndarray:
    """GPS Factor error function
    :param measurement: GPS measurement, to be filled with `partial`
    :param this: gtsam.CustomFactor handle
    :param values: gtsam.Values
    :param H: Optional list of Jacobians
    :return: the unwhitened error
    """
    
    key = this.keys()[0]
    estimate_pose = values.atPose2(key)
    estimate_position = np.array([estimate_pose.x(), estimate_pose.y()])
    error = estimate_position - measurement

    if H is not None:
        H[0] = np.array([[1, 0, 0], [0, 1, 0]])

    return error

# %%
unaryNoise = gtsam.noiseModel.Diagonal.Sigmas([0.1, 0.1])
graph.add(gtsam.CustomFactor(unaryNoise, [1], partial(error_gps, np.array([0.0, 0.0]))))
graph.add(gtsam.CustomFactor(unaryNoise, [2], partial(error_gps, np.array([2.0, 0.0]))))
graph.add(gtsam.CustomFactor(unaryNoise, [3], partial(error_gps, np.array([4.0, 0.0]))))
graph.print()
# Out:
# NonlinearFactorGraph: size: 6
#
# Factor 0: PriorFactor on 1
#   prior mean:  (0, 0, 0)
#   noise model: diagonal sigmas [0.3; 0.3; 0.1];
#
# Factor 1: BetweenFactor(1,2)
#   measured:  (2, 0, 0)
#   noise model: diagonal sigmas [0.2; 0.2; 0.1];
#
# Factor 2: BetweenFactor(2,3)
#   measured:  (2, 0, 0)
#   noise model: diagonal sigmas [0.2; 0.2; 0.1];
#
# Factor 3: CustomFactor on 1
# isotropic dim=2 sigma=0.1
#
# Factor 4: CustomFactor on 2
# isotropic dim=2 sigma=0.1
#
# Factor 5: CustomFactor on 3
# isotropic dim=2 sigma=0.1

# %%
result = gtsam.LevenbergMarquardtOptimizer(graph, initial).optimize()
result.print("Result:\n")
# Out:
# Result:
#
# Values with 3 values:
# Value 1: (gtsam::Pose2)
# (-9.27935405e-17, 3.49728654e-18, 4.98922465e-19)
#
# Value 2: (gtsam::Pose2)
# (2, 3.67247512e-19, 5.49918357e-19)
#
# Value 3: (gtsam::Pose2)
# (4, -3.92959853e-19, 6.75866117e-19)

# %%
marginals = gtsam.Marginals(graph, result)
np.set_printoptions(precision=4, suppress=True)
# marginals.print("Marginals:\n")
print("x1 covariance:\n" + str(marginals.marginalCovariance(1)))
print("x2 covariance:\n" + str(marginals.marginalCovariance(2)))
print("x3 covariance:\n" + str(marginals.marginalCovariance(3)))
# Out:
# x1 covariance:
# [[ 0.0076  0.     -0.    ]
#  [ 0.      0.0081 -0.0015]
#  [-0.     -0.0015  0.0045]]
# x2 covariance:
# [[ 0.0071  0.     -0.    ]
#  [ 0.      0.0077 -0.0014]
#  [-0.     -0.0014  0.0072]]
# x3 covariance:
# [[0.0083 0.     0.    ]
#  [0.     0.0092 0.0026]
#  [0.     0.0026 0.0172]]

# %%
gtsam_plot.plot_pose2(0, result.atPose2(1), 0.5, marginals.marginalCovariance(1))
gtsam_plot.plot_pose2(0, result.atPose2(2), 0.5, marginals.marginalCovariance(2))
gtsam_plot.plot_pose2(0, result.atPose2(3), 0.5, marginals.marginalCovariance(3), ("x-axis", "y-axis", "theta-axis"))
plt.axis('equal')
plt.grid('on')
plt.show()

# %% [markdown]
# ## 4 PoseSLAM

# %%
graph = gtsam.NonlinearFactorGraph()

priorNoise = gtsam.noiseModel.Diagonal.Sigmas(np.array([0.3, 0.3, 0.1]))
graph.add(gtsam.PriorFactorPose2(1, gtsam.Pose2(0.0, 0.0, 0.0), priorNoise))

# Add odometry factors
model = gtsam.noiseModel.Diagonal.Sigmas(np.array([0.2, 0.2, 0.1]))
graph.add(gtsam.BetweenFactorPose2(1, 2, gtsam.Pose2(2.0, 0.0, 0.0), model))
graph.add(gtsam.BetweenFactorPose2(2, 3, gtsam.Pose2(2.0, 0.0, np.pi/2), model))
graph.add(gtsam.BetweenFactorPose2(3, 4, gtsam.Pose2(2.0, 0.0, np.pi/2), model))
graph.add(gtsam.BetweenFactorPose2(4, 5, gtsam.Pose2(2.0, 0.0, np.pi/2), model))

# Add pose constraint
graph.add(gtsam.BetweenFactorPose2(5, 2, gtsam.Pose2(2.0, 0.0, np.pi/2), model))

# %%
initialEstimate = gtsam.Values()
initialEstimate.insert(1, gtsam.Pose2(0.1, 0.2, 0.15))
initialEstimate.insert(2, gtsam.Pose2(2.3, 0.1, -0.2))
initialEstimate.insert(3, gtsam.Pose2(4.1, -0.1, 0.1))
initialEstimate.insert(4, gtsam.Pose2(4.3, 1.6, 1.5))
initialEstimate.insert(5, gtsam.Pose2(2.5, 2.2, 2.9))

result = gtsam.LevenbergMarquardtOptimizer(graph, initialEstimate).optimize()
result.print()
# Out:
# Values with 5 values:
# Value 1: (gtsam::Pose2)
# (-4.04275228e-17, -5.2450694e-18, -6.74061164e-18)
#
# Value 2: (gtsam::Pose2)
# (2, -2.10573769e-17, -1.23156529e-17)
#
# Value 3: (gtsam::Pose2)
# (4, -9.65790365e-14, 1.57079633)
#
# Value 4: (gtsam::Pose2)
# (4, 2, -3.14159265)
#
# Value 5: (gtsam::Pose2)
# (2, 2, -1.57079633)

# %%
marginals = gtsam.Marginals(graph, result)
np.set_printoptions(precision=4, suppress=True)
#marginals.print("Marginals:\n")
print("x1 covariance:\n" + str(marginals.marginalCovariance(1)))
print("x2 covariance:\n" + str(marginals.marginalCovariance(2)))
print("x3 covariance:\n" + str(marginals.marginalCovariance(3)))
print("x4 covariance:\n" + str(marginals.marginalCovariance(4)))
print("x5 covariance:\n" + str(marginals.marginalCovariance(5)))
# Out:
# x1 covariance:
# [[ 0.09 -0.    0.  ]
#  [-0.    0.09 -0.  ]
#  [ 0.   -0.    0.01]]
# x2 covariance:
# [[0.13 0.   0.  ]
#  [0.   0.17 0.02]
#  [0.   0.02 0.02]]
# x3 covariance:
# [[ 0.362  -0.      0.062 ]
#  [-0.      0.162  -0.002 ]
#  [ 0.062  -0.002   0.0265]]
# x4 covariance:
# [[ 0.268 -0.128  0.048]
#  [-0.128  0.378 -0.068]
#  [ 0.048 -0.068  0.028]]
# x5 covariance:
# [[ 0.202   0.036  -0.018 ]
#  [ 0.036   0.26   -0.051 ]
#  [-0.018  -0.051   0.0265]]

# %%
fig = plt.figure()
axes = fig.gca()

gtsam_plot.plot_pose2_on_axes(axes, result.atPose2(1), 0.4, marginals.marginalCovariance(1))
gtsam_plot.plot_pose2_on_axes(axes, result.atPose2(2), 0.4, marginals.marginalCovariance(2))
gtsam_plot.plot_pose2_on_axes(axes, result.atPose2(3), 0.4, marginals.marginalCovariance(3))
gtsam_plot.plot_pose2_on_axes(axes, result.atPose2(4), 0.4, marginals.marginalCovariance(4))
gtsam_plot.plot_pose2_on_axes(axes, result.atPose2(5), 0.4, marginals.marginalCovariance(5))
plt.grid('on')

# %% [markdown]
# ## 4.3 Reading and Optimizing Pose Graphs

# %%
datafile = gtsam.findExampleDataFile('w100.graph')
model = gtsam.noiseModel.Diagonal.Sigmas(np.array([0.05, 0.05, 5*np.pi/180]))

[graph, initial] = gtsam.load2D(datafile, model)

# %%
initial
# Out:
# Values with 100 values:
# Value 0: (gtsam::Pose2)
# (0, 0, 0)
#
# Value 1: (gtsam::Pose2)
# (0.995595, 0.0837204, 0.0146728)
#
# Value 2: (gtsam::Pose2)
# (2.0463, 0.0352563, -0.0332615)
#
# Value 3: (gtsam::Pose2)
# (3.01173, 0.00117694, -0.0153904)
#
# Value 4: (gtsam::Pose2)
# (4.00973, -0.0790194, -0.02875)
#
# Value 5: (gtsam::Pose2)
# (5.0196, -0.0664912, -0.039715)
#
# Value 6: (gtsam::Pose2)
# (5.02744, 0.934341, 1.51768)
#
# Value 7: (gtsam::Pose2)
# (5.04775, 1.89323, 1.51033)
#
# Value 8: (gtsam::Pose2)
# (5.15306, 2.87418, 1.49866)
#
# Value 9: (gtsam::Pose2)
# (5.22304, 3.87497, 1.48364)
#
# Value 10: (gtsam::Pose2)
# (5.23596, 4.87041, 1.47951)
#
# Value 11: (gtsam::Pose2)
# (4.24581, 4.94796, 2.99944)
#
# Value 12: (gtsam::Pose2)
# (3.22758, 5.09551, 2.99492)
#
# Value 13: (gtsam::Pose2)
# (2.19142, 5.16887, 2.98707)
#
# Value 14: (gtsam::Pose2)
# (1.1311, 5.24329, 2.97244)
#
# Value 15: (gtsam::Pose2)
# (0.158988, 5.30427, 2.95438)
#
# Value 16: (gtsam::Pose2)
# (-0.12526, 4.26995, -1.76551)
#
# Value 17: (gtsam::Pose2)
# (-0.25431, 3.29165, -1.77099)
#
# Value 18: (gtsam::Pose2)
# (-0.413555, 2.30595, -1.76019)
#
# Value 19: (gtsam::Pose2)
# (-0.536073, 1.30685, -1.75991)
#
# Value 20: (gtsam::Pose2)
# (-0.808468, 0.302589, -1.76466)
#
# Value 21: (gtsam::Pose2)
# (0.165652, 0.0941948, -0.204681)
#
# Value 22: (gtsam::Pose2)
# (1.09464, -0.0109951, -0.196319)
#
# Value 23: (gtsam::Pose2)
# (2.15691, -0.187264, -0.20809)
#
# Value 24: (gtsam::Pose2)
# (3.19115, -0.448207, -0.192611)
#
# Value 25: (gtsam::Pose2)
# (4.13241, -0.636131, -0.162687)
#
# Value 26: (gtsam::Pose2)
# (4.34104, 0.512161, 1.44413)
#
# Value 27: (gtsam::Pose2)
# (4.44536, 1.59548, 1.42312)
#
# Value 28: (gtsam::Pose2)
# (4.57241, 2.60423, 1.37618)
#
# Value 29: (gtsam::Pose2)
# (4.86591, 3.53433, 1.35616)
#
# Value 30: (gtsam::Pose2)
# (5.11392, 4.4801, 1.35985)
#
# Value 31: (gtsam::Pose2)
# (4.21358, 4.6527, 2.91174)
#
# Value 32: (gtsam::Pose2)
# (3.22654, 4.82431, 2.94929)
#
# Value 33: (gtsam::Pose2)
# (2.23774, 5.00761, 2.97485)
#
# Value 34: (gtsam::Pose2)
# (1.22736, 5.20153, 2.98412)
#
# Value 35: (gtsam::Pose2)
# (0.123255, 5.26802, 2.9767)
#
# Value 36: (gtsam::Pose2)
# (0.00632935, 4.33864, -1.76346)
#
# Value 37: (gtsam::Pose2)
# (-0.10879, 3.36173, -1.7901)
#
# Value 38: (gtsam::Pose2)
# (-0.321951, 2.4384, -1.78648)
#
# Value 39: (gtsam::Pose2)
# (-0.543773, 1.34377, -1.77905)
#
# Value 40: (gtsam::Pose2)
# (-0.658597, 0.382801, -1.78632)
#
# Value 41: (gtsam::Pose2)
# (0.317835, 0.0716759, -0.235552)
#
# Value 42: (gtsam::Pose2)
# (1.3002, -0.181376, -0.217406)
#
# Value 43: (gtsam::Pose2)
# (2.34947, -0.372484, -0.22532)
#
# Value 44: (gtsam::Pose2)
# (3.34502, -0.63322, -0.236028)
#
# Value 45: (gtsam::Pose2)
# (4.3567, -0.866613, -0.24513)
#
# Value 46: (gtsam::Pose2)
# (4.61743, 0.074884, 1.32649)
#
# Value 47: (gtsam::Pose2)
# (4.7283, 1.10386, 1.31325)
#
# Value 48: (gtsam::Pose2)
# (4.88942, 2.06218, 1.34353)
#
# Value 49: (gtsam::Pose2)
# (5.1224, 3.05224, 1.34)
#
# Value 50: (gtsam::Pose2)
# (5.37031, 3.89715, 1.33962)
#
# Value 51: (gtsam::Pose2)
# (4.40295, 4.12271, 2.91276)
#
# Value 52: (gtsam::Pose2)
# (3.40284, 4.39024, 2.9116)
#
# Value 53: (gtsam::Pose2)
# (2.43673, 4.61578, 2.93887)
#
# Value 54: (gtsam::Pose2)
# (1.51408, 4.75597, 2.91757)
#
# Value 55: (gtsam::Pose2)
# (0.505735, 4.96923, 2.92324)
#
# Value 56: (gtsam::Pose2)
# (0.256695, 4.01175, -1.78543)
#
# Value 57: (gtsam::Pose2)
# (0.0116126, 2.99092, -1.79932)
#
# Value 58: (gtsam::Pose2)
# (-0.153788, 2.07052, -1.80614)
#
# Value 59: (gtsam::Pose2)
# (-0.31455, 1.12993, -1.83961)
#
# Value 60: (gtsam::Pose2)
# (-0.593175, 0.109086, -1.83163)
#
# Value 61: (gtsam::Pose2)
# (-1.51899, 0.241119, 2.87633)
#
# Value 62: (gtsam::Pose2)
# (-2.44041, 0.564876, 2.86065)
#
# Value 63: (gtsam::Pose2)
# (-3.38567, 0.881461, 2.88557)
#
# Value 64: (gtsam::Pose2)
# (-4.33636, 1.15673, 2.87003)
#
# Value 65: (gtsam::Pose2)
# (-5.3523, 1.33309, 2.88766)
#
# Value 66: (gtsam::Pose2)
# (-5.08987, 2.28075, 1.31311)
#
# Value 67: (gtsam::Pose2)
# (-4.8429, 3.23082, 1.32403)
#
# Value 68: (gtsam::Pose2)
# (-4.59105, 4.20251, 1.31499)
#
# Value 69: (gtsam::Pose2)
# (-4.38824, 5.10708, 1.32873)
#
# Value 70: (gtsam::Pose2)
# (-4.13462, 5.98725, 1.31402)
#
# Value 71: (gtsam::Pose2)
# (-5.15517, 6.29412, 2.90024)
#
# Value 72: (gtsam::Pose2)
# (-6.16852, 6.57768, 2.91315)
#
# Value 73: (gtsam::Pose2)
# (-7.19212, 6.7759, 2.90733)
#
# Value 74: (gtsam::Pose2)
# (-8.19083, 6.96321, 2.87753)
#
# Value 75: (gtsam::Pose2)
# (-9.21776, 7.31653, 2.85231)
#
# Value 76: (gtsam::Pose2)
# (-9.46536, 6.44658, -1.86253)
#
# Value 77: (gtsam::Pose2)
# (-9.70116, 5.60413, -1.86719)
#
# Value 78: (gtsam::Pose2)
# (-10.0031, 4.63377, -1.8642)
#
# Value 79: (gtsam::Pose2)
# (-10.2892, 3.70939, -1.85209)
#
# Value 80: (gtsam::Pose2)
# (-10.5468, 2.73555, -1.86536)
#
# Value 81: (gtsam::Pose2)
# (-9.53131, 2.42844, -0.348286)
#
# Value 82: (gtsam::Pose2)
# (-8.67728, 2.03155, -0.326912)
#
# Value 83: (gtsam::Pose2)
# (-7.76543, 1.7035, -0.340149)
#
# Value 84: (gtsam::Pose2)
# (-6.72871, 1.23422, -0.332391)
#
# Value 85: (gtsam::Pose2)
# (-5.7871, 0.960473, -0.298466)
#
# Value 86: (gtsam::Pose2)
# (-6.15287, -0.0181319, -1.84594)
#
# Value 87: (gtsam::Pose2)
# (-6.48069, -0.957942, -1.82387)
#
# Value 88: (gtsam::Pose2)
# (-6.74441, -1.90271, -1.83019)
#
# Value 89: (gtsam::Pose2)
# (-6.98263, -2.8633, -1.82672)
#
# Value 90: (gtsam::Pose2)
# (-7.25581, -3.79723, -1.7991)
#
# Value 91: (gtsam::Pose2)
# (-6.24938, -3.97274, -0.228747)
#
# Value 92: (gtsam::Pose2)
# (-5.2193, -4.22592, -0.231118)
#
# Value 93: (gtsam::Pose2)
# (-4.2791, -4.41808, -0.244412)
#
# Value 94: (gtsam::Pose2)
# (-3.27605, -4.63989, -0.262869)
#
# Value 95: (gtsam::Pose2)
# (-2.21195, -4.90921, -0.241867)
#
# Value 96: (gtsam::Pose2)
# (-1.9446, -3.94139, 1.35224)
#
# Value 97: (gtsam::Pose2)
# (-1.7284, -2.88069, 1.34979)
#
# Value 98: (gtsam::Pose2)
# (-1.4787, -1.9068, 1.36613)
#
# Value 99: (gtsam::Pose2)
# (-1.32193, -0.941704, 1.35348)

# %%
# Add a Gaussian prior on pose x_0
priorMean = gtsam.Pose2(0, 0, 0)
priorNoise = gtsam.noiseModel.Diagonal.Sigmas(np.array([0.01, 0.01, 0.01]))
graph.add(gtsam.PriorFactorPose2(0, priorMean, priorNoise))

# %%
# Optimize using Levenberg-Marquardt optimization and get marginals
optimizer = gtsam.LevenbergMarquardtOptimizer(graph, initial)
result = optimizer.optimize()
marginals = gtsam.Marginals(graph, result)  

print("Graph error (initial):", graph.error(initial))
print("Graph error (result):", graph.error(result))
# Out:
# Graph error (initial): 15027.033279873533
# Graph error (result): 213.3046076935409

# %%
# Plot result
#gtsam_plot.plot_trajectory(fignum=1, values=initial, scale=0.5)

fig = plt.figure(1)
fig.set_size_inches(12, 8)
ax = fig.gca()  # 2D axes

poses2 = gtsam.utilities.allPose2s(result)
for k in poses2.keys():
    P = marginals.marginalCovariance(k)  # 3x3 Pose2 covariance
    gtsam_plot.plot_pose2_on_axes(ax, poses2.atPose2(k),
                                  axis_length=0.5, covariance=P)

ax.set_aspect('equal', adjustable='box')
ax.set_xlabel('X'); ax.set_ylabel('Y')
plt.show()

# %%
datafile = gtsam.findExampleDataFile('sphere2500.txt')
model = gtsam.noiseModel.Diagonal.Sigmas(np.array([0.05, 0.05, 0.1, 0.1, 0.1]))
[graph, initial] = gtsam.load3D(datafile) # initial is empty

# Plot initial estimate (requires a 3D plotting function, e.g., plot3DTrajectory)
gtsam_plot.plot_trajectory(fignum=1, values=initial, scale=0.5)

# Read again, now with all constraints, and optimize
# graph = gtsam.load3D(datafile, model)
# graph.add(gtsam.NonlinearEqualityPose3(0, initial.atPose3(0)))
# optimizer = gtsam.LevenbergMarquardtOptimizer(graph, initial)
# result = optimizer.optimizeSafely()

# Plot optimized result (requires a 3D plotting function)
# plot3DTrajectory(result, 'r-', False)
# plt.axis('equal')

# %% [markdown]
# ## 5 Landmark-based SLAM

# %% [markdown]
# # Grid

# %%
fg = gtsam.NonlinearFactorGraph()
init_values = gtsam.Values()

N = 3

def node_key(i, j):
    return X(i*N+j)

for i in range(N):
    for j in range(N):
        gt = gtsam.Point2(i, j)
        z = gt + np.random.normal(0, 0.1, size=2)
        init_values.insert(node_key(i, j), z)
        
for i in range(N):
    for j in range(N-1):
        factor1 = gtsam.RangeFactor2(
            node_key(i, j), 
            node_key(i, j+1), 
            1.0, 
            gtsam.noiseModel.Isotropic.Sigma(1, 0.1)
        )
        factor2 = gtsam.RangeFactor2(
            node_key(j, i), 
            node_key(j+1, i), 
            1.0, 
            gtsam.noiseModel.Isotropic.Sigma(1, 0.1)
        )
        
        fg.add(factor1)
        fg.add(factor2)

fg.add(gtsam.PriorFactorPoint2(node_key(0, 0), gtsam.Point2(0, 0), gtsam.noiseModel.Isotropic.Sigma(2, 0.1)))

optimizer = gtsam.LevenbergMarquardtOptimizer(fg, init_values)
result = optimizer.optimize()
print("Optimized values:")
for i in range(N):
    for j in range(N):
        print(f"Node ({i}, {j}): {result.atPoint2(node_key(i, j))}")    

initial_xy = []
optimized_xy = []
for i in range(N):
    for j in range(N):
        key = node_key(i, j)
        initial_xy.append(init_values.atPoint2(key))
        optimized_xy.append(result.atPoint2(key))

initial_xy = np.array(initial_xy)
optimized_xy = np.array(optimized_xy)

plt.figure(figsize=(6, 6))
plt.scatter(initial_xy[:, 0], initial_xy[:, 1], label="Initial", marker="x", s=80)
plt.scatter(optimized_xy[:, 0], optimized_xy[:, 1], label="Optimized", marker="o", s=50)

for start, end in zip(initial_xy, optimized_xy):
    plt.plot([start[0], end[0]], [start[1], end[1]], color="gray", alpha=0.4, linewidth=1)

plt.axis("equal")
plt.grid(True)
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.title("Initial vs optimized Point2 values")
plt.show()
# Out:
# Optimized values:
# Node (0, 0): [0. 0.]
# Node (0, 1): [0.0403 0.9992]
# Node (0, 2): [-0.0539  1.9947]
# Node (1, 0): [1.     0.0068]
# Node (1, 1): [1.0403 1.006 ]
# Node (1, 2): [0.9461 2.0015]
# Node (2, 0): [ 1.9987 -0.0446]
# Node (2, 1): [2.039  0.9546]
# Node (2, 2): [1.9448 1.9502]

# %%
# Same grid example, but with relative position measurements (dx, dy)
fg_relative = gtsam.NonlinearFactorGraph()
init_relative = gtsam.Values()

N = 3

def node_key(i, j):
    return X(i*N+j)

for i in range(N):
    for j in range(N):
        gt = gtsam.Point2(i, j)
        z = gt + np.random.normal(0, 0.5, size=2)
        init_relative.insert(node_key(i, j), z)

relative_noise = gtsam.noiseModel.Isotropic.Sigma(2, 0.1)

for i in range(N):
    for j in range(N - 1):
        fg_relative.add(gtsam.BetweenFactorPoint2(
            node_key(i, j),
            node_key(i, j + 1),
            gtsam.Point2(0.0, 1.0),
            relative_noise,
        ))
        fg_relative.add(gtsam.BetweenFactorPoint2(
            node_key(j, i),
            node_key(j + 1, i),
            gtsam.Point2(1.0, 0.0),
            relative_noise,
        ))

fg_relative.add(gtsam.PriorFactorPoint2(
    node_key(0, 0),
    gtsam.Point2(0, 0),
    gtsam.noiseModel.Isotropic.Sigma(2, 0.1),
))

optimizer = gtsam.LevenbergMarquardtOptimizer(fg_relative, init_relative)
result_relative = optimizer.optimize()
marginals_relative = gtsam.Marginals(fg_relative, result_relative)

print("Optimized values with relative position factors:")
for i in range(N):
    for j in range(N):
        print(f"Node ({i}, {j}): {result_relative.atPoint2(node_key(i, j))}")

from matplotlib.patches import Ellipse

def covariance_ellipse(mean, covariance, n_std=2.0, **kwargs):
    eigvals, eigvecs = np.linalg.eigh(covariance)
    order = eigvals.argsort()[::-1]
    eigvals = eigvals[order]
    eigvecs = eigvecs[:, order]
    angle = np.degrees(np.arctan2(eigvecs[1, 0], eigvecs[0, 0]))
    width, height = 2 * n_std * np.sqrt(eigvals)
    return Ellipse(xy=mean, width=width, height=height, angle=angle, **kwargs)

initial_xy = []
optimized_xy = []
optimized_covariances = []
for i in range(N):
    for j in range(N):
        key = node_key(i, j)
        initial_xy.append(init_relative.atPoint2(key))
        optimized_xy.append(result_relative.atPoint2(key))
        optimized_covariances.append(marginals_relative.marginalCovariance(key))

initial_xy = np.array(initial_xy)
optimized_xy = np.array(optimized_xy)

fig, ax = plt.subplots(figsize=(6, 6))
ax.scatter(initial_xy[:, 0], initial_xy[:, 1], label="Initial", marker="x", s=80)
ax.scatter(optimized_xy[:, 0], optimized_xy[:, 1], label="Optimized", marker="o", s=50)

for start, end in zip(initial_xy, optimized_xy):
    ax.plot([start[0], end[0]], [start[1], end[1]], color="gray", alpha=0.4, linewidth=1)

for mean, covariance in zip(optimized_xy, optimized_covariances):
    ax.add_patch(covariance_ellipse(mean, covariance, edgecolor="tab:blue", facecolor="none", alpha=0.5))

ax.axis("equal")
ax.grid(True)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.legend()
ax.set_title("Relative position factors: initial vs optimized")
plt.show()
# Out:
# Optimized values with relative position factors:
# Node (0, 0): [0. 0.]
# Node (0, 1): [0. 1.]
# Node (0, 2): [0. 2.]
# Node (1, 0): [1. 0.]
# Node (1, 1): [1. 1.]
# Node (1, 2): [1. 2.]
# Node (2, 0): [2. 0.]
# Node (2, 1): [2. 1.]
# Node (2, 2): [2. 2.]

# %%
# Plot each optimizer step for the relative-position graph.
step_optimizer = gtsam.LevenbergMarquardtOptimizer(fg_relative, init_relative)
step_values = [init_relative]
step_errors = [fg_relative.error(init_relative)]

max_steps = 10
error_tol = 1e-9

for _ in range(max_steps):
    previous_error = step_optimizer.error()
    step_optimizer.iterate()
    current_values = step_optimizer.values()
    current_error = fg_relative.error(current_values)
    step_values.append(current_values)
    step_errors.append(current_error)

    if abs(previous_error - current_error) < error_tol:
        break

cols = min(4, len(step_values))
rows = int(np.ceil(len(step_values) / cols))
fig, axes = plt.subplots(rows, cols, figsize=(4 * cols, 4 * rows), squeeze=False)

for step_idx, values in enumerate(step_values):
    ax = axes[step_idx // cols, step_idx % cols]
    xy = np.array([
        values.atPoint2(node_key(i, j))
        for i in range(N)
        for j in range(N)
    ])

    ax.scatter(initial_xy[:, 0], initial_xy[:, 1], label="Initial", marker="x", s=55, alpha=0.45)
    ax.scatter(xy[:, 0], xy[:, 1], label="Step value", marker="o", s=45)

    previous_xy = initial_xy if step_idx == 0 else np.array([
        step_values[step_idx - 1].atPoint2(node_key(i, j))
        for i in range(N)
        for j in range(N)
    ])

    for start, end in zip(previous_xy, xy):
        ax.plot([start[0], end[0]], [start[1], end[1]], color="gray", alpha=0.25, linewidth=1)

    ax.axis("equal")
    ax.grid(True)
    ax.set_title(f"Step {step_idx}, error={step_errors[step_idx]:.3g}")

for ax in axes.flat[len(step_values):]:
    ax.axis("off")

handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right")
fig.suptitle("Levenberg-Marquardt intermediate values")
fig.tight_layout()
plt.show()

# %%
# Nonlinear grid example with bearing/range measurements.
import gtsam
import matplotlib.pyplot as plt
import numpy as np
from gtsam.symbol_shorthand import L, X
from matplotlib.patches import Ellipse

fg_br = gtsam.NonlinearFactorGraph()
init_br = gtsam.Values()

N = 3

def node_idx(i, j):
    return i * N + j

def point_key(i, j):
    return L(node_idx(i, j))

def pose_key(i, j):
    return X(node_idx(i, j))

def covariance_ellipse(mean, covariance, n_std=2.0, **kwargs):
    eigvals, eigvecs = np.linalg.eigh(covariance)
    order = eigvals.argsort()[::-1]
    eigvals = eigvals[order]
    eigvecs = eigvecs[:, order]
    angle = np.degrees(np.arctan2(eigvecs[1, 0], eigvecs[0, 0]))
    width, height = 2 * n_std * np.sqrt(eigvals)
    return Ellipse(xy=mean, width=width, height=height, angle=angle, **kwargs)

pose_noise = gtsam.noiseModel.Diagonal.Sigmas(np.array([1e-3, 1e-3, 1e-3]))
bearing_range_noise = gtsam.noiseModel.Diagonal.Sigmas(np.array([0.03, 0.05]))
landmark_prior_noise = gtsam.noiseModel.Isotropic.Sigma(2, 0.1)

gt_poses = {}
gt_points = {}

for i in range(N):
    for j in range(N):
        idx = node_idx(i, j)
        gt_pose = gtsam.Pose2(i - 0.35, j - 0.25, 0.15)
        gt_point = gtsam.Point2(i, j)
        gt_poses[idx] = gt_pose
        gt_points[idx] = gt_point

        init_br.insert(pose_key(i, j), gt_pose)
        init_br.insert(point_key(i, j), gt_point + np.random.normal(0, 0.35, size=2))
        fg_br.add(gtsam.PriorFactorPose2(pose_key(i, j), gt_pose, pose_noise))

fg_br.add(gtsam.PriorFactorPoint2(point_key(0, 0), gtsam.Point2(0, 0), landmark_prior_noise))

for i in range(N):
    for j in range(N):
        source_pose = gt_poses[node_idx(i, j)]
        for ni, nj in [(i, j), (i + 1, j), (i, j + 1)]:
            if ni >= N or nj >= N:
                continue

            target_point = gt_points[node_idx(ni, nj)]
            measured_bearing = gtsam.BearingRange2D.MeasureBearing(source_pose, target_point)
            measured_range = gtsam.BearingRange2D.MeasureRange(source_pose, target_point)
            fg_br.add(gtsam.BearingRangeFactor2D(
                pose_key(i, j),
                point_key(ni, nj),
                measured_bearing,
                measured_range,
                bearing_range_noise,
            ))

optimizer_br = gtsam.LevenbergMarquardtOptimizer(fg_br, init_br)
result_br = optimizer_br.optimize()
marginals_br = gtsam.Marginals(fg_br, result_br)

initial_xy = []
optimized_xy = []
optimized_covariances = []
for i in range(N):
    for j in range(N):
        key = point_key(i, j)
        initial_xy.append(init_br.atPoint2(key))
        optimized_xy.append(result_br.atPoint2(key))
        optimized_covariances.append(marginals_br.marginalCovariance(key))

initial_xy = np.array(initial_xy)
optimized_xy = np.array(optimized_xy)

fig, ax = plt.subplots(figsize=(6, 6))
ax.scatter(initial_xy[:, 0], initial_xy[:, 1], label="Initial landmarks", marker="x", s=80)
ax.scatter(optimized_xy[:, 0], optimized_xy[:, 1], label="Optimized landmarks", marker="o", s=50)

for start, end in zip(initial_xy, optimized_xy):
    ax.plot([start[0], end[0]], [start[1], end[1]], color="gray", alpha=0.4, linewidth=1)

for mean, covariance in zip(optimized_xy, optimized_covariances):
    ax.add_patch(covariance_ellipse(mean, covariance, edgecolor="tab:blue", facecolor="none", alpha=0.5))

ax.axis("equal")
ax.grid(True)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.legend()
ax.set_title("Bearing/range factors: initial vs optimized")
plt.show()

step_optimizer_br = gtsam.LevenbergMarquardtOptimizer(fg_br, init_br)
step_values_br = [init_br]
step_errors_br = [fg_br.error(init_br)]

max_steps = 10
error_tol = 1e-9

for _ in range(max_steps):
    previous_error = step_optimizer_br.error()
    step_optimizer_br.iterate()
    current_values = step_optimizer_br.values()
    current_error = fg_br.error(current_values)
    step_values_br.append(current_values)
    step_errors_br.append(current_error)

    if abs(previous_error - current_error) < error_tol:
        break

cols = min(4, len(step_values_br))
rows = int(np.ceil(len(step_values_br) / cols))
fig, axes = plt.subplots(rows, cols, figsize=(4 * cols, 4 * rows), squeeze=False)

for step_idx, values in enumerate(step_values_br):
    ax = axes[step_idx // cols, step_idx % cols]
    xy = np.array([
        values.atPoint2(point_key(i, j))
        for i in range(N)
        for j in range(N)
    ])

    ax.scatter(initial_xy[:, 0], initial_xy[:, 1], label="Initial", marker="x", s=55, alpha=0.45)
    ax.scatter(xy[:, 0], xy[:, 1], label="Step value", marker="o", s=45)

    previous_xy = initial_xy if step_idx == 0 else np.array([
        step_values_br[step_idx - 1].atPoint2(point_key(i, j))
        for i in range(N)
        for j in range(N)
    ])

    for start, end in zip(previous_xy, xy):
        ax.plot([start[0], end[0]], [start[1], end[1]], color="gray", alpha=0.25, linewidth=1)

    ax.axis("equal")
    ax.grid(True)
    ax.set_title(f"Step {step_idx}, error={step_errors_br[step_idx]:.3g}")

for ax in axes.flat[len(step_values_br):]:
    ax.axis("off")

handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right")
fig.suptitle("Bearing/range Levenberg-Marquardt intermediate values")
fig.tight_layout()
plt.show()

# %%
a = np.array([[1, 0.5, 3], [0.5, 1, 3]])
len(a)
# Out:
# 2
